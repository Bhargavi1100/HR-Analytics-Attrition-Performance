# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Load The Dataset

# %%
data=pd.read_csv("Dataset.csv")

# %%
columns = data.columns.tolist()
print(columns)
num_columns = data.shape[1]
print(f'The dataset has {num_columns} columns.')
# Out:
# ['Age', 'Attrition', 'Education', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MonthlyIncome', 'OverTime', 'PerformanceRating', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsSinceLastPromotion']
# The dataset has 15 columns.

# %% [markdown]
# Summary And Structure Of The Dataset

# %%
data.head()
# Out:
#    Age Attrition  Education  EnvironmentSatisfaction  JobInvolvement  \
# 0   41       Yes          2                        2               3
# 1   49        No          1                        3               2
# 2   37       Yes          2                        4               2
# 3   33        No          4                        4               3
# 4   27        No          1                        1               3
#
#    JobLevel                JobRole  JobSatisfaction  MonthlyIncome OverTime  \
# 0         2        Sales Executive                4           5993      Yes
# 1         2     Research Scientist                2           5130       No
# 2         1  Laboratory Technician                3           2090      Yes
# 3         1     Research Scientist                3           2909      Yes
# 4         1  Laboratory Technician                2           3468       No
#
#    PerformanceRating  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# ...

# %%
data.tail()
# Out:
#       Age Attrition  Education  EnvironmentSatisfaction  JobInvolvement  \
# 1465   36        No          2                        3               4
# 1466   39        No          1                        4               2
# 1467   27        No          3                        2               4
# 1468   49        No          3                        4               2
# 1469   34        No          3                        2               4
#
#       JobLevel                    JobRole  JobSatisfaction  MonthlyIncome  \
# 1465         2      Laboratory Technician                4           2571
# 1466         3  Healthcare Representative                1           9991
# 1467         2     Manufacturing Director                2           6142
# 1468         2            Sales Executive                2           5390
# 1469         2      Laboratory Technician                3           4404
#
#      OverTime  PerformanceRating  TrainingTimesLastYear  WorkLifeBalance  \
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'Education', 'EnvironmentSatisfaction',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MonthlyIncome', 'OverTime', 'PerformanceRating',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsSinceLastPromotion'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   Attrition                1470 non-null   object
#  2   Education                1470 non-null   int64
#  3   EnvironmentSatisfaction  1470 non-null   int64
#  4   JobInvolvement           1470 non-null   int64
#  5   JobLevel                 1470 non-null   int64
#  6   JobRole                  1470 non-null   object
#  7   JobSatisfaction          1470 non-null   int64
#  8   MonthlyIncome            1470 non-null   int64
#  9   OverTime                 1470 non-null   object
#  10  PerformanceRating        1470 non-null   int64
#  11  TrainingTimesLastYear    1470 non-null   int64
#  12  WorkLifeBalance          1470 non-null   int64
#  13  YearsAtCompany           1470 non-null   int64
# ...

# %%
data.describe()
# Out:
#                Age    Education  EnvironmentSatisfaction  JobInvolvement  \
# count  1470.000000  1470.000000              1470.000000     1470.000000
# mean     36.923810     2.912925                 2.721769        2.729932
# std       9.135373     1.024165                 1.093082        0.711561
# min      18.000000     1.000000                 1.000000        1.000000
# 25%      30.000000     2.000000                 2.000000        2.000000
# 50%      36.000000     3.000000                 3.000000        3.000000
# 75%      43.000000     4.000000                 4.000000        3.000000
# max      60.000000     5.000000                 4.000000        4.000000
#
#           JobLevel  JobSatisfaction  MonthlyIncome  PerformanceRating  \
# count  1470.000000      1470.000000    1470.000000        1470.000000
# mean      2.063946         2.728571    6502.931293           3.153741
# std       1.106940         1.102846    4707.956783           0.360824
# ...

# %% [markdown]
# Checking For Missing Values

# %%
data.isnull().any()
# Out:
# Age                        False
# Attrition                  False
# Education                  False
# EnvironmentSatisfaction    False
# JobInvolvement             False
# JobLevel                   False
# JobRole                    False
# JobSatisfaction            False
# MonthlyIncome              False
# OverTime                   False
# PerformanceRating          False
# TrainingTimesLastYear      False
# WorkLifeBalance            False
# YearsAtCompany             False
# YearsSinceLastPromotion    False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# Education                  0
# EnvironmentSatisfaction    0
# JobInvolvement             0
# JobLevel                   0
# JobRole                    0
# JobSatisfaction            0
# MonthlyIncome              0
# OverTime                   0
# PerformanceRating          0
# TrainingTimesLastYear      0
# WorkLifeBalance            0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# dtype: int64

# %%
missing_percentage = (data.isnull().sum() / len(data)) * 100

print(missing_percentage)
# Out:
# Age                        0.0
# Attrition                  0.0
# Education                  0.0
# EnvironmentSatisfaction    0.0
# JobInvolvement             0.0
# JobLevel                   0.0
# JobRole                    0.0
# JobSatisfaction            0.0
# MonthlyIncome              0.0
# OverTime                   0.0
# PerformanceRating          0.0
# TrainingTimesLastYear      0.0
# WorkLifeBalance            0.0
# YearsAtCompany             0.0
# YearsSinceLastPromotion    0.0
# dtype: float64

# %% [markdown]
# Check For Duplicates

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Outlier Detection

# %%
plt.subplot(3,4,2)
sns.boxplot(data['Age'])

plt.subplot(3,4,4)
sns.boxplot(data['Attrition'])

plt.subplot(3,4,6)
sns.boxplot(data['Education'])

plt.subplot(3,4,8)
sns.boxplot(data['EnvironmentSatisfaction'])

plt.subplot(3,4,10)
sns.boxplot(data['JobInvolvement'])

plt.subplot(3,4,12)
sns.boxplot(data['JobLevel'])
plt.show()

plt.subplot(3,4,2)
sns.boxplot(data['JobRole'])

plt.subplot(3,4,4)
sns.boxplot(data['JobSatisfaction'])

plt.subplot(3,4,6)
sns.boxplot(data['MonthlyIncome'])
plt.show()

plt.subplot(3,4,2)
sns.boxplot(data['OverTime'])

plt.subplot(3,4,4)
sns.boxplot(data['PerformanceRating'])

plt.subplot(3,4,6)
sns.boxplot(data['TrainingTimesLastYear'])

plt.subplot(3,4,8)
sns.boxplot(data['WorkLifeBalance'])

plt.subplot(3,4,10)
sns.boxplot(data['YearsAtCompany'])

plt.subplot(3,4,12)
sns.boxplot(data['YearsSinceLastPromotion'])

plt.show()

# %% [markdown]
# Outlier Detection And Removal

# %%
data['MonthlyIncome'] = data['MonthlyIncome'].clip(lower=data['MonthlyIncome'].quantile(0.09),upper=data['MonthlyIncome'].quantile(0.91))
data['TrainingTimesLastYear'] = data['TrainingTimesLastYear'].clip(lower=data['TrainingTimesLastYear'].quantile(0.14),upper=data['TrainingTimesLastYear'].quantile(0.85))
data['YearsAtCompany'] = data['YearsAtCompany'].clip(lower=data['YearsAtCompany'].quantile(0.09),upper=data['YearsAtCompany'].quantile(0.91))
data['YearsSinceLastPromotion'] = data['YearsSinceLastPromotion'].clip(lower=data['YearsSinceLastPromotion'].quantile(0.09),upper=data['YearsSinceLastPromotion'].quantile(0.91))

# %%
plt.figure(figsize=(20,15))

plt.subplot(2,2,1)       
sns.boxplot(data['MonthlyIncome'])  

plt.subplot(2,2,3)       
sns.boxplot(data['TrainingTimesLastYear'])  

plt.subplot(2,2,4)       
sns.boxplot(data['YearsAtCompany'])  
plt.show()

plt.figure(figsize=(20,15))
plt.subplot(2,2,2)       
sns.boxplot(data['YearsSinceLastPromotion'])  
plt.show()

# %% [markdown]
# Step 1:Attrition Analysis

# %% [markdown]
# EDA

# %%
data.head()
# Out:
#    Age Attrition  Education  EnvironmentSatisfaction  JobInvolvement  \
# 0   41       Yes          2                        2               3
# 1   49        No          1                        3               2
# 2   37       Yes          2                        4               2
# 3   33        No          4                        4               3
# 4   27        No          1                        1               3
#
#    JobLevel                JobRole  JobSatisfaction  MonthlyIncome OverTime  \
# 0         2        Sales Executive                4        5993.00      Yes
# 1         2     Research Scientist                2        5130.00       No
# 2         1  Laboratory Technician                3        2288.21      Yes
# 3         1     Research Scientist                3        2909.00      Yes
# 4         1  Laboratory Technician                2        3468.00       No
#
#    PerformanceRating  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   Attrition                1470 non-null   object
#  2   Education                1470 non-null   int64
#  3   EnvironmentSatisfaction  1470 non-null   int64
#  4   JobInvolvement           1470 non-null   int64
#  5   JobLevel                 1470 non-null   int64
#  6   JobRole                  1470 non-null   object
#  7   JobSatisfaction          1470 non-null   int64
#  8   MonthlyIncome            1470 non-null   float64
#  9   OverTime                 1470 non-null   object
#  10  PerformanceRating        1470 non-null   int64
#  11  TrainingTimesLastYear    1470 non-null   int64
#  12  WorkLifeBalance          1470 non-null   int64
#  13  YearsAtCompany           1470 non-null   int64
# ...

# %%
data.describe()
# Out:
#                Age    Education  EnvironmentSatisfaction  JobInvolvement  \
# count  1470.000000  1470.000000              1470.000000     1470.000000
# mean     36.923810     2.912925                 2.721769        2.729932
# std       9.135373     1.024165                 1.093082        0.711561
# min      18.000000     1.000000                 1.000000        1.000000
# 25%      30.000000     2.000000                 2.000000        2.000000
# 50%      36.000000     3.000000                 3.000000        3.000000
# 75%      43.000000     4.000000                 4.000000        3.000000
# max      60.000000     5.000000                 4.000000        4.000000
#
#           JobLevel  JobSatisfaction  MonthlyIncome  PerformanceRating  \
# count  1470.000000      1470.000000    1470.000000        1470.000000
# mean      2.063946         2.728571    6267.511857           3.153741
# std       1.106940         1.102846    4040.508774           0.360824
# ...

# %%
jobrole=data['JobRole'].value_counts()
print(jobrole)
attrition=data['Attrition'].value_counts()
print(attrition)
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.pairplot(data[['Age', 'Attrition', 'Education', 'EnvironmentSatisfaction',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
       'MonthlyIncome', 'OverTime', 'PerformanceRating',
       'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
       'YearsSinceLastPromotion']])
plt.show()

# %%
numerical_data = data.select_dtypes(include=['float64', 'int64'])

# %%
correlation_matrix = numerical_data.corr(method='pearson')
print(correlation_matrix)
# Out:
#                               Age  Education  EnvironmentSatisfaction  \
# Age                      1.000000   0.208034                 0.010146
# Education                0.208034   1.000000                -0.027128
# EnvironmentSatisfaction  0.010146  -0.027128                 1.000000
# JobInvolvement           0.029820   0.042438                -0.008278
# JobLevel                 0.509604   0.101589                 0.001212
# JobSatisfaction         -0.004892  -0.011296                -0.006784
# MonthlyIncome            0.496104   0.102159                -0.010245
# PerformanceRating        0.001904  -0.024539                -0.029548
# TrainingTimesLastYear    0.011134  -0.016908                -0.019664
# WorkLifeBalance         -0.021490   0.009819                 0.027627
# YearsAtCompany           0.266289   0.065824                 0.004512
# YearsSinceLastPromotion  0.187917   0.054168                 0.019873
#
# ...

# %% [markdown]
# Correlation Analysis:Numeric Variables

# %% [markdown]
# +1: Perfect positive correlation (as one variable increases, the other increases).
#
# -1: Perfect negative correlation (as one variable increases, the other decreases).
#
#  0: No correlation.

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
data = pd.read_csv('Dataset.csv')

# %%
data['Attrition'] = data['Attrition'].map({'Yes': 1, 'No': 0})
data['OverTime'] = data['OverTime'].map({'Yes': 1, 'No': 0})

# %%
print(data.columns)
# Out:
# Index(['Age', 'Attrition', 'Education', 'EnvironmentSatisfaction',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MonthlyIncome', 'OverTime', 'PerformanceRating',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsSinceLastPromotion'],
#       dtype='object')

# %%
# Use only 'JobRole' since 'Department' is not in your dataset
data = pd.get_dummies(data, columns=['JobRole'], drop_first=True)

# %%
features = ['OverTime', 'MonthlyIncome', 'JobSatisfaction', 'WorkLifeBalance', 'YearsAtCompany']

# %%
features.extend([col for col in data.columns if 'JobRole_' in col or 'Department_' in col])

# %%
X = data[features]
y = data['Attrition']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
log_model = LogisticRegression(max_iter=2000)  # Increase max_iter if necessary
log_model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=2000)

# %%
y_pred = log_model.predict(X_test)
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       380
#            1       0.59      0.16      0.26        61
#
#     accuracy                           0.87       441
#    macro avg       0.73      0.57      0.59       441
# weighted avg       0.84      0.87      0.83       441
#
# [[373   7]
#  [ 51  10]]
# Accuracy: 0.8684807256235828

# %%
coefficients = pd.Series(log_model.coef_[0], index=X.columns)
coefficients.plot(kind='bar')
plt.title('Logistic Regression Coefficients')
plt.show()
